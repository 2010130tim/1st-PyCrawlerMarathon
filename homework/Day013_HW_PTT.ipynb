# %% [markdown]
# # PTT 網路爬蟲實作練習
#
#
# * 能夠利用 Request + BeatifulSour 撰寫爬蟲，並存放到合適的資料結構

# %% [markdown]
# ## 作業目標
#
# 根據範例 ，完成以下問題：
#
# * ① 印出最新文章的「作者」「標題」「時間」
# * ② 印出第一頁所有文章的「作者」「標題」「時間」

# %% [markdown]
# ### ① 印出最新文章的「作者」「標題」「時間」

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
url='https://www.ptt.cc/bbs/NBA/index.html'
r=requests.get(url)
soup=BeautifulSoup(r.text)
print(soup)
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>看板 NBA 文章列表 - 批踢踢實業坊</title>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
# <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
# </head>
# <body>
# <div id="topbar-container">
# <div class="bbs-content" id="topbar">
# <a href="/bbs/" id="logo">批踢踢實業坊</a>
# <span>›</span>
# <a class="board" href="/bbs/NBA/index.html"><span class="board-label">看板 </span>NBA</a>
# <a class="right small" href="/about.html">關於我們</a>
# <a class="right small" href="/contact.html">聯絡資訊</a>
# </div>
# </div>
# <div id="main-container">
# <div id="action-bar-container">
# <div class="action-bar">
# <div class="btn-group btn-group-dir">
# <a class="btn selected" href="/bbs/NBA/index.html">看板</a>
# <a class="btn" href="/man/NBA/index.html">精華區</a>
# </div>
# <div class="btn-group btn-group-paging">
# <a class="btn wide" href="/bbs/NBA/index1.html">最舊</a>
# <a class="btn wide" href="/bbs/NBA/index6503.html">‹ 上頁</a>
# <a class="btn wide disabled">下頁 ›</a>
# <a class="btn wide" href="/bbs/NBA/index.html">最新</a>
# </div>
# </div>
# </div>
# <div class="r-list-container action-bar-margin bbs-screen">
# <div class="search-bar">
# <form action="search" id="search-bar" type="get">
# <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
# </form>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">18</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576479564.A.A06.html">Re: [情報] 嘴綠快攻空拋打板傳球....隊友沒人接到</a>
# </div>
# <div class="meta">
# <div class="author">kairiyu</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E5%98%B4%E7%B6%A0%E5%BF%AB%E6%94%BB%E7%A9%BA%E6%8B%8B%E6%89%93%E6%9D%BF%E5%82%B3%E7%90%83....%E9%9A%8A%E5%8F%8B%E6%B2%92%E4%BA%BA%E6%8E%A5%E5%88%B0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Akairiyu">搜尋看板內 kairiyu 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">12</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576480467.A.09D.html">[新聞] 布萊德索將休兵2週 字母哥：球隊有足夠深</a>
# </div>
# <div class="meta">
# <div class="author">phoenix286</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%B8%83%E8%90%8A%E5%BE%B7%E7%B4%A2%E5%B0%87%E4%BC%91%E5%85%B52%E9%80%B1+%E5%AD%97%E6%AF%8D%E5%93%A5%EF%BC%9A%E7%90%83%E9%9A%8A%E6%9C%89%E8%B6%B3%E5%A4%A0%E6%B7%B1">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aphoenix286">搜尋看板內 phoenix286 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">30</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576481052.A.A04.html">[情報] 真的很難！格林賽後爆粗口：從各個角度來</a>
# </div>
# <div class="meta">
# <div class="author">kakala99</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E7%9C%9F%E7%9A%84%E5%BE%88%E9%9B%A3%EF%BC%81%E6%A0%BC%E6%9E%97%E8%B3%BD%E5%BE%8C%E7%88%86%E7%B2%97%E5%8F%A3%EF%BC%9A%E5%BE%9E%E5%90%84%E5%80%8B%E8%A7%92%E5%BA%A6%E4%BE%86">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Akakala99">搜尋看板內 kakala99 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576482033.A.40A.html">[花邊] 奧尼爾曬OK組合和詹眉組合對位圖：2對2你</a>
# </div>
# <div class="meta">
# <div class="author">KyrieIrving1</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E5%A5%A7%E5%B0%BC%E7%88%BE%E6%9B%ACOK%E7%B5%84%E5%90%88%E5%92%8C%E8%A9%B9%E7%9C%89%E7%B5%84%E5%90%88%E5%B0%8D%E4%BD%8D%E5%9C%96%EF%BC%9A2%E5%B0%8D2%E4%BD%A0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AKyrieIrving1">搜尋看板內 KyrieIrving1 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">20</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576482429.A.D46.html">[花邊] LBJ談Carter: 他是史上最佳的實戰扣將</a>
# </div>
# <div class="meta">
# <div class="author">ColeNorris</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+LBJ%E8%AB%87Carter%3A+%E4%BB%96%E6%98%AF%E5%8F%B2%E4%B8%8A%E6%9C%80%E4%BD%B3%E7%9A%84%E5%AF%A6%E6%88%B0%E6%89%A3%E5%B0%87">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AColeNorris">搜尋看板內 ColeNorris 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">61</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576482503.A.54F.html">[外絮] Woj: 現在的火箭正處在危急關頭</a>
# </div>
# <div class="meta">
# <div class="author">pneumo</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%A4%96%E7%B5%AE%5D+Woj%3A+%E7%8F%BE%E5%9C%A8%E7%9A%84%E7%81%AB%E7%AE%AD%E6%AD%A3%E8%99%95%E5%9C%A8%E5%8D%B1%E6%80%A5%E9%97%9C%E9%A0%AD">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Apneumo">搜尋看板內 pneumo 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">49</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576482555.A.1A3.html">Re: [討論] 健康的Fultz好可怕</a>
# </div>
# <div class="meta">
# <div class="author">ios5566</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%A8%8E%E8%AB%96%5D+%E5%81%A5%E5%BA%B7%E7%9A%84Fultz%E5%A5%BD%E5%8F%AF%E6%80%95">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aios5566">搜尋看板內 ios5566 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">25</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576483791.A.D30.html">[新聞] 羅素本季暫留勇士機會高 沃神：季中交易</a>
# </div>
# <div class="meta">
# <div class="author">asdf1256</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E7%BE%85%E7%B4%A0%E6%9C%AC%E5%AD%A3%E6%9A%AB%E7%95%99%E5%8B%87%E5%A3%AB%E6%A9%9F%E6%9C%83%E9%AB%98+%E6%B2%83%E7%A5%9E%EF%BC%9A%E5%AD%A3%E4%B8%AD%E4%BA%A4%E6%98%93">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aasdf1256">搜尋看板內 asdf1256 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">17</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576483813.A.BD5.html">[花邊] 湖人客場14連勝 平聯盟史上第3長紀錄</a>
# </div>
# <div class="meta">
# <div class="author">thnlkj0665</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E6%B9%96%E4%BA%BA%E5%AE%A2%E5%A0%B414%E9%80%A3%E5%8B%9D+%E5%B9%B3%E8%81%AF%E7%9B%9F%E5%8F%B2%E4%B8%8A%E7%AC%AC3%E9%95%B7%E7%B4%80%E9%8C%84">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Athnlkj0665">搜尋看板內 thnlkj0665 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">33</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576485360.A.D13.html">[新聞] 3度遭熱火禁賽 威斯特飯碗恐不保</a>
# </div>
# <div class="meta">
# <div class="author">Israfil</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+3%E5%BA%A6%E9%81%AD%E7%86%B1%E7%81%AB%E7%A6%81%E8%B3%BD+%E5%A8%81%E6%96%AF%E7%89%B9%E9%A3%AF%E7%A2%97%E6%81%90%E4%B8%8D%E4%BF%9D">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AIsrafil">搜尋看板內 Israfil 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">38</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576487467.A.A0B.html">[新聞] 國王29失誤仍贏球 柯爾：從沒看過</a>
# </div>
# <div class="meta">
# <div class="author">Angel0724</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%9C%8B%E7%8E%8B29%E5%A4%B1%E8%AA%A4%E4%BB%8D%E8%B4%8F%E7%90%83+%E6%9F%AF%E7%88%BE%EF%BC%9A%E5%BE%9E%E6%B2%92%E7%9C%8B%E9%81%8E">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AAngel0724">搜尋看板內 Angel0724 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">28</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576487532.A.B2F.html">[花邊] Hayward社交媒體曬照，與女兒們歡度聖誕派對</a>
# </div>
# <div class="meta">
# <div class="author">kairiyu</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+Hayward%E7%A4%BE%E4%BA%A4%E5%AA%92%E9%AB%94%E6%9B%AC%E7%85%A7%EF%BC%8C%E8%88%87%E5%A5%B3%E5%85%92%E5%80%91%E6%AD%A1%E5%BA%A6%E8%81%96%E8%AA%95%E6%B4%BE%E5%B0%8D">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Akairiyu">搜尋看板內 kairiyu 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">13</span></div>
# <div class="title">
#
# 				(已被Vedan刪除) &lt;snakeback&gt;1-1(150)
#
# 			</div>
# <div class="meta">
# <div class="author">-</div>
# <div class="article-menu">
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">15</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576490484.A.6C8.html">Re: [花邊] 奧尼爾曬OK組合和詹眉組合對位圖：2對2你</a>
# </div>
# <div class="meta">
# <div class="author">boyen0917</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E8%8A%B1%E9%82%8A%5D+%E5%A5%A7%E5%B0%BC%E7%88%BE%E6%9B%ACOK%E7%B5%84%E5%90%88%E5%92%8C%E8%A9%B9%E7%9C%89%E7%B5%84%E5%90%88%E5%B0%8D%E4%BD%8D%E5%9C%96%EF%BC%9A2%E5%B0%8D2%E4%BD%A0">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aboyen0917">搜尋看板內 boyen0917 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">30</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576492139.A.53F.html">[公告] 是否禁止記者鄭廷瑋文章投票開始</a>
# </div>
# <div class="meta">
# <div class="author">dragon803</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%98%AF%E5%90%A6%E7%A6%81%E6%AD%A2%E8%A8%98%E8%80%85%E9%84%AD%E5%BB%B7%E7%91%8B%E6%96%87%E7%AB%A0%E6%8A%95%E7%A5%A8%E9%96%8B%E5%A7%8B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Adragon803">搜尋看板內 dragon803 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">5</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576492957.A.FE5.html">Re: [情報] 真的很難！格林賽後爆粗口：從各個角度來</a>
# </div>
# <div class="meta">
# <div class="author">smallkaka</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E7%9C%9F%E7%9A%84%E5%BE%88%E9%9B%A3%EF%BC%81%E6%A0%BC%E6%9E%97%E8%B3%BD%E5%BE%8C%E7%88%86%E7%B2%97%E5%8F%A3%EF%BC%9A%E5%BE%9E%E5%90%84%E5%80%8B%E8%A7%92%E5%BA%A6%E4%BE%86">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Asmallkaka">搜尋看板內 smallkaka 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">81</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576493243.A.38D.html">[情報] KD在場下推Irving</a>
# </div>
# <div class="meta">
# <div class="author">sa92219</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+KD%E5%9C%A8%E5%A0%B4%E4%B8%8B%E6%8E%A8Irving">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Asa92219">搜尋看板內 sa92219 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-list-sep"></div>
# <div class="r-ent">
# <div class="nrec"></div>
# <div class="title">
# <a href="/bbs/NBA/M.1558698194.A.1DC.html">[公告] 板規v6.6</a>
# </div>
# <div class="meta">
# <div class="author">Vedan</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%9D%BF%E8%A6%8Fv6.6">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AVedan">搜尋看板內 Vedan 的文章</a></div>
# </div>
# </div>
# <div class="date"> 5/24</div>
# <div class="mark">!</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f1">爆</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1561360084.A.52D.html">[公告] 樂透取消及未來不再開啟樂透</a>
# </div>
# <div class="meta">
# <div class="author">Vedan</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%A8%82%E9%80%8F%E5%8F%96%E6%B6%88%E5%8F%8A%E6%9C%AA%E4%BE%86%E4%B8%8D%E5%86%8D%E9%96%8B%E5%95%9F%E6%A8%82%E9%80%8F">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AVedan">搜尋看板內 Vedan 的文章</a></div>
# </div>
# </div>
# <div class="date"> 6/24</div>
# <div class="mark">M</div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">38</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1571971445.A.8A8.html">[公告] 版主上任相關事項 </a>
# </div>
# <div class="meta">
# <div class="author">qazwsx879345</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E7%89%88%E4%B8%BB%E4%B8%8A%E4%BB%BB%E7%9B%B8%E9%97%9C%E4%BA%8B%E9%A0%85+">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Aqazwsx879345">搜尋看板內 qazwsx879345 的文章</a></div>
# </div>
# </div>
# <div class="date">10/25</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f3">23</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1574959564.A.46A.html">[情報] SEASON Schedule 賽程 December 19–20</a>
# </div>
# <div class="meta">
# <div class="author">JerroLi</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+SEASON+Schedule+%E8%B3%BD%E7%A8%8B+December+19%E2%80%9320">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3AJerroLi">搜尋看板內 JerroLi 的文章</a></div>
# </div>
# </div>
# <div class="date">11/29</div>
# <div class="mark"></div>
# </div>
# </div>
# <div class="r-ent">
# <div class="nrec"><span class="hl f2">7</span></div>
# <div class="title">
# <a href="/bbs/NBA/M.1576492139.A.53F.html">[公告] 是否禁止記者鄭廷瑋文章投票開始</a>
# </div>
# <div class="meta">
# <div class="author">dragon803</div>
# <div class="article-menu">
# <div class="trigger">⋯</div>
# <div class="dropdown">
# <div class="item"><a href="/bbs/NBA/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E6%98%AF%E5%90%A6%E7%A6%81%E6%AD%A2%E8%A8%98%E8%80%85%E9%84%AD%E5%BB%B7%E7%91%8B%E6%96%87%E7%AB%A0%E6%8A%95%E7%A5%A8%E9%96%8B%E5%A7%8B">搜尋同標題文章</a></div>
# <div class="item"><a href="/bbs/NBA/search?q=author%3Adragon803">搜尋看板內 dragon803 的文章</a></div>
# </div>
# </div>
# <div class="date">12/16</div>
# <div class="mark"></div>
# </div>
# </div>
# </div>
# </div>
# <script>
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
# </script>
# <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js"></script>
# <script src="//images.ptt.cc/bbs/v2.27/bbs.js"></script>
# </body>
# </html>

# %%
items = soup.findAll(True, {"class": re.compile(r'(r-ent|r-list-sep)')})
for item in range(len(items)):
    if 'r-list-sep' in items[item].attrs['class']:
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc'+items[item-1].a['href']).text, "html5lib")
            article = []
            for info in r.find_all(class_='article-meta-value'):
                article.append(info.text)
            print('作者: {}\n標題: {}\n時間: {}'.format(article[0], article[2], article[-1]))
        except:
            continue
# Out:
# 作者: sa92219 (sa92219)
# 標題: [情報] KD在場下推Irving
# 時間: Mon Dec 16 18:47:21 2019

# %% [markdown]
# ### ② 印出第一頁所有文章的「作者」「標題」「時間」

# %%
columns = ['作者', '看板', '標題', '時間']
def GetFistPageInfo(url):
    r = requests.get(url)
    
    soup = BeautifulSoup(r.text, "html5lib")
    
    articles = []
    
    for d in soup.find_all(class_="title"):
        try:
            r = BeautifulSoup(requests.get('https://www.ptt.cc'+d.find('a')['href']).text, "html5lib")
            article = []
            for info in r.find_all(class_='article-meta-value'):
                article.append(info.text)
            articles.append(article)
        except:
            continue
    df = pd.DataFrame(articles, columns=columns)
    
    return df

GetFistPageInfo('https://www.ptt.cc/bbs/NBA/index1.html')
# Out:
#                              作者   看板                         標題  \
# 0                 Price (Price)  NBA    [轉錄]Lyotard 對於太陽板討論串的結論
# 1                 Price (Price)  NBA        [公告] 請停止一切關於本次活動的發言
# 2               Frankaze (神采風華)  NBA   [轉錄]跟之前那篇比起來 我覺得這篇也應該轉過來
# 3               Frankaze (神采風華)  NBA                [轉錄]再轉一篇好文來
# 4                 Price (Price)  NBA           [轉錄][情報] 夏洛特山貓系列
# 5                 Price (Price)  NBA   [轉錄]Re: [心得] 真是受不了糗爺....
# 6                 Price (Price)  NBA            [轉錄]總冠軍賽NO.2觀後感
# 7   AmuroNamie (原來太嗨真的會失眠^___^)  NBA       [心得] Rasheed Wallace
# 8                  toptree (  )  NBA                    掌控球賽的男人
# 9            skchang (3EB板開板囉！)  NBA        [閒聊] 說說2004季後賽名場面回顧
# 10                   shineup ()  NBA     [心得] 其實說穿了 就是活塞的防守太可怕了
# 11                    cOvi (喵~)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 12               ykshih (￼N￼Ns)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 13              Frankaze (神采風華)  NBA    Re: [閒聊] 說說2004季後賽名場面回顧
# 14                Price (Price)  NBA        [轉錄]Re: 總冠軍賽NO.3觀後感
# 15              Frankaze (神采風華)  NBA        [轉錄]Re: 總冠軍賽NO.3觀後感
# 16          star1 (第一次魔術表演不算成功)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 17              coldspring (笑笑)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
# 18                 airbear (地圖)  NBA  Re: Kobe is frustrated...
# 19            pennykidd (andre)  NBA    Re: [轉錄]Re: 總冠軍賽NO.3觀後感
#
#                           時間
# 0   Sun May 16 01:54:33 2004
# 1   Mon May 24 00:43:00 2004
# 2   Tue Jun  8 01:16:45 2004
# 3   Tue Jun  8 09:02:23 2004
# 4   Thu Jun 10 00:39:35 2004
# 5   Thu Jun 10 00:51:35 2004
# 6   Thu Jun 10 12:05:07 2004
# 7   Fri Jun 11 15:06:09 2004
# 8   Sat Jun 12 07:13:04 2004
# 9   Sat Jun 12 13:21:49 2004
# 10  Sat Jun 12 13:12:47 2004
# 11  Sat Jun 12 16:43:07 2004
# 12  Sat Jun 12 17:26:37 2004
# 13  Sat Jun 12 18:34:46 2004
# 14  Mon Jun 14 02:18:52 2004
# 15  Mon Jun 14 02:34:33 2004
# 16  Mon Jun 14 07:16:30 2004
# 17  Mon Jun 14 09:24:57 2004
# 18  Mon Jun 14 12:56:14 2004
# 19  Mon Jun 14 22:07:01 2004

# %% [markdown]
# ### ③ 試著爬爬看其他版的文章

# %%
GetFistPageInfo('https://www.ptt.cc/bbs/C_Chat/index.html')
# Out:
#                          作者      看板                                標題  \
# 0      MiharuHubby (點兔喵教掌門)  C_Chat  Re: [新聞] 日本一父親狂砸兒子3台Switch 發文炫耀育
# 1           rronbang (Ron1)  C_Chat              [閒聊] ASL是不是很少出現夏番的歌?
# 2               kamiyo (神予)  C_Chat        [閒聊] telegram GBF討論群組招收心血啦
# 3           asd8603 (人醜真衰小)  C_Chat                [閒聊]  戰女的敗筆484遊戲名稱
# 4            hayate232 (CY)  C_Chat      [討論] warframe 星戰已經變成 移動防禦了..
# 5           vikk33 (vikk33)  C_Chat         [情報]  海外產值首次突破1兆日元，日本動畫產業
# 6        phoenix286 (糰子大家族)  C_Chat            [推投] 《喜歡本大爺的就你一個？》人氣投票
# 7             kid725 (凱道基德)  C_Chat                    [問題] 有沒有女性版爆豪?
# 8           vikk33 (vikk33)  C_Chat          [情報]  社長提前跑路果然是倒下了，《時光碎片
# 9        Lex4193 (慟!!遊戲倦怠期)  C_Chat  Re: [新聞] 日本一父親狂砸兒子3台Switch 發文炫耀育
# 10        nutssummer (煎粿一下)  C_Chat      Re: [五等分] 102/113 的果汁 ＆ Kiss
# 11        zouelephant (毛毛象)  C_Chat               [討論] 讀書時聽東西真的有辦法專心嗎
# 12    jack86326 (最好也最壞的世界線)  C_Chat           [閒聊] 木棉花YT開放票選 年假上架哪部作品
# 13         vct886 (October)  C_Chat             [閒聊] 演員 act-age 94 火焰
# 14            LSLLtu (如雨隨行)  C_Chat         Re: [聲優] 大眾動畫觀眾會不在意有沒有大牌聲
# 15    kenkenken31 (葫蘆裏頭裝瓠瓜)  C_Chat         [情報]《我的英雄學院 唯我正義2》新遊戲影片!!
# 16             Baychu (月桂丘)  C_Chat                    [閒聊] 斗篷女是不是很騷？
# 17        EMIRU720 (自我循環主義)  C_Chat  Re: [新聞] 日本一父親狂砸兒子3台Switch 發文炫耀育
# 18   tsukiyomi157 (草莓口味☆肥宅)  C_Chat               Re: [閒聊] 大家的老婆初音結婚了
# 19       jschenlemn (sinra)  C_Chat  [公告] C_Chat板板規v.16.3.0+板務建議+好文補M
# 20      durantjosh (肚爛特‧喬許)  C_Chat     [19秋] 2019年秋番 台灣觀賞管道整理(10/01)
# 21  SaberTheBest (Saber最高!)  C_Chat                   [19秋] 秋番各作品首播時間
# 22  SaberTheBest (Saber最高!)  C_Chat                   [20冬] 冬番各作品首播時間
# 23       jschenlemn (sinra)  C_Chat        [公告] 看板活動& 臨時板規與公告彙整& 閒聊區
#
#                           時間
# 0   Mon Dec 16 19:51:58 2019
# 1   Mon Dec 16 19:53:23 2019
# 2   Mon Dec 16 19:58:38 2019
# 3   Mon Dec 16 20:01:23 2019
# 4   Mon Dec 16 20:01:41 2019
# 5   Mon Dec 16 20:04:26 2019
# 6   Mon Dec 16 20:04:46 2019
# 7   Mon Dec 16 20:06:05 2019
# 8   Mon Dec 16 20:08:14 2019
# 9   Mon Dec 16 20:10:29 2019
# 10  Mon Dec 16 20:12:28 2019
# 11  Mon Dec 16 20:13:11 2019
# 12  Mon Dec 16 20:13:32 2019
# 13  Mon Dec 16 20:14:04 2019
# 14  Mon Dec 16 20:15:58 2019
# 15  Mon Dec 16 20:17:02 2019
# 16  Mon Dec 16 20:24:47 2019
# 17  Mon Dec 16 20:28:13 2019
# 18  Mon Dec 16 20:42:12 2019
# 19  Sat Sep 14 01:23:34 2019
# 20  Tue Oct  1 22:07:42 2019
# 21  Sun Sep 15 13:41:11 2019
# 22  Thu Dec 12 22:57:46 2019
# 23  Mon Dec 16 10:22:11 2019
